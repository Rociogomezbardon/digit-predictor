# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('train/loss.csv')
df.plot(kind='scatter',x='epoch',y='loss',color='red',ylim=(0,0.01))
#plt.show()

# %%
import torch
print("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# cuda

# %%
import torch
a = torch.cuda.FloatTensor([1.])
